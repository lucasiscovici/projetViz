# %%
import pandas as pd

# %%
go=pd.read_table("./gordon-2002_database.txt",header=,index_col=0)

# %%
go.index = ["type"]+go.index[1:].tolist()

# %%
go.head()
# Out:
#            meso42 meso51  meso2 meso82 meso212  meso74  meso67  meso57  \
# type          MPM    MPM    MPM    MPM     MPM     MPM     MPM     MPM
# 1006_at        10     71   11.3   24.6    22.8      10    19.3    20.7
# 1014_at        82  133.9   60.7   85.1    49.9   108.2    74.2    38.4
# 1042_at    1481.1   82.6  796.8   13.5   561.8  1209.3  1102.5  1895.5
# 1047_s_at   220.3   74.5  298.3   26.6    85.9    40.3   196.8     228
#
#           meso167  meso33      ...       CL2001032149AA CL2001032301AA  \
# type          MPM     MPM      ...                   AD             AD
# 1006_at      17.7      10      ...                 21.8           73.7
# 1014_at      75.1    69.8      ...                 36.3             10
# 1042_at    1095.8  3114.3      ...                 52.8          122.3
# 1047_s_at   112.7   260.4      ...                171.8             10
#
#           CL2001032307AA CL2001032040AA CL2001032842AA CL2001032259AA  \
# ...
